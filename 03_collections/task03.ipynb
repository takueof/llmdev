# %%
filename = "todo_list.txt"
try:
    with open(filename, "r", encoding="utf-8") as file:
        todo_list = [line.strip() for line in file]
except FileNotFoundError:
    todo_list = []

print("【TODOリスト】")

while True:
    print("番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:", end="", flush=True)
    choice = input("")

    if choice == "1":
        print("1:追加", flush=True)
        add_todo = input("追加するTODO:")
        print("追加するTODO:", add_todo, flush=True)
        todo_list.append(add_todo)
    elif choice == "2":
        print("2:表示", flush=True)
        for i, todo in enumerate(todo_list):
            print(f"{i}. {todo}")
    elif choice == "3":
        print("3:削除", flush=True)
        for i, todo in enumerate(todo_list):
            print(f"{i}. {todo}")
        try:
            index_input = input("削除する番号:")
            print("削除する番号:", index_input, flush=True)
            index = int(index_input)
            if index < 0:
                raise ValueError("負の値は指定できません")
            if todo_list[index]:
                del todo_list[index]
            else:
                raise IndexError("範囲外の番号は指定できません")
        except Exception as error:
            print("無効な番号です。", flush=True)
    elif choice == "4":
        print("4:保存と終了", flush=True)
        with open(filename, "w", encoding="utf-8") as file:
            file.writelines(f"{todo}\n" for todo in todo_list)
        print("TODOリストを保存して終了します。", flush=True)
        break
    else:
        print("1-4の数字を入力してください。", flush=True)
# Out:
# 【TODOリスト】
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  1
# 1:追加
# 追加するTODO: a
# 追加するTODO: a
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  1
# 1:追加
# 追加するTODO: b
# 追加するTODO: b
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  2
# 2:表示
# 0. a
# 1. b
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  3
# 3:削除
# 0. a
# 1. b
# 削除する番号: 2
# 削除する番号: 2
# 無効な番号です。
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  2
# 2:表示
# 0. a
# 1. b
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  3
# 3:削除
# 0. a
# 1. b
# 削除する番号: a
# 削除する番号: a
# 無効な番号です。
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  2
# 2:表示
# 0. a
# 1. b
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
# 1-4の数字を入力してください。
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  3
# 3:削除
# 0. a
# 1. b
# 削除する番号:
# 削除する番号:
# 無効な番号です。
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  3
# 3:削除
# 0. a
# 1. b
# 削除する番号: 1
# 削除する番号: 1
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  2
# 2:表示
# 0. a
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:
#  4
# 4:保存と終了
# TODOリストを保存して終了します。
