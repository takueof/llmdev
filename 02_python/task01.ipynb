# %%
fullname = "渡邉卓"
age = 40

print(
    "はじめまして、",
    fullname,
    "と申します。\n年齢は",
    age,
    "歳です。来年は",
    age + 1,
    "歳になります。\nよろしくお願いします。",
)
# Out:
# はじめまして、 渡邉卓 と申します。
# 年齢は 40 歳です。来年は 41 歳になります。
# よろしくお願いします。
