# %%
principal = int(input("元金（初期投資額）を入力してください："))
annualInterestRate = float(input("年利（パーセンテージ）を入力してください："))
amount = float(principal);
years = 10;

for i in range(years):
    amount *= (1.0 + (annualInterestRate / 100.0))

print(f"{years}年後の金額：{amount}")
# Out:
# 元金（初期投資額）を入力してください： 1000
# 年利（パーセンテージ）を入力してください： 5
# 10年後の金額：1628.8946267774422
